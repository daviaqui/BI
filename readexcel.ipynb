# %%
import pandas as pd

# %%
tabela = pd.read_csv('MICRODADOS.csv', encoding='latin1', sep=';')
tabela.head()
# Out:
# C:\Users\davia\AppData\Local\Temp\ipykernel_16032\3875971643.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   tabela = pd.read_csv('MICRODADOS.csv', encoding='latin1', sep=';')
#   DataNotificacao DataCadastro DataDiagnostico DataColeta_RT_PCR  \
# 0      2023-03-23   2023-03-23      2023-03-23               NaN
# 1      2023-03-23   2023-03-23      2022-12-18               NaN
# 2      2023-03-23   2023-03-23      2023-03-23               NaN
# 3      2023-03-23   2023-03-23      2023-03-19               NaN
# 4      2023-03-23   2023-03-23      2023-03-21               NaN
#
#   DataColetaTesteRapido DataColetaSorologia DataColetaSorologiaIGG  \
# 0            2023-03-23                 NaN                    NaN
# 1            2022-11-22                 NaN                    NaN
# 2            2023-03-23                 NaN                    NaN
# 3            2023-03-23                 NaN                    NaN
# ...

# %%
dados = tabela.query('Municipio == "CARIACICA" & ComorbidadeTabagismo == "Sim" & DataObito > "2019" & Evolucao == "Óbito pelo COVID-19"')
display(dados)
# Out:
#         DataNotificacao DataCadastro DataDiagnostico DataColeta_RT_PCR  \
# 113151       2022-12-29   2022-12-29      2022-12-27               NaN
# 678077       2022-07-13   2022-07-13      2022-07-12        2022-07-13
# 800286       2022-07-04   2022-07-04      2022-07-04               NaN
# 816942       2022-07-04   2022-07-04      2022-07-04        2022-07-04
# 968067       2022-06-22   2022-06-22      2022-06-19               NaN
# ...                 ...          ...             ...               ...
# 4724946      2020-05-08   2020-05-08      2020-05-03        2020-05-08
# 4725771      2020-05-07   2020-05-08      2020-05-04        2020-05-07
# 4730142      2020-05-04   2020-05-04      2020-04-25        2020-05-05
# 4730683      2020-05-03   2020-05-03      2020-05-01        2020-05-02
# 4740642      2020-04-20   2020-04-20      2020-04-13        2020-04-20
#
#         DataColetaTesteRapido DataColetaSorologia DataColetaSorologiaIGG  \
# ...

# %%
dados[['Municipio' , 'ComorbidadeTabagismo' , 'DataObito', 'Evolucao' ]]
# Out:
#          Municipio ComorbidadeTabagismo   DataObito             Evolucao
# 113151   CARIACICA                  Sim  2023-01-10  Óbito pelo COVID-19
# 678077   CARIACICA                  Sim  2022-07-14  Óbito pelo COVID-19
# 800286   CARIACICA                  Sim  2022-01-23  Óbito pelo COVID-19
# 816942   CARIACICA                  Sim  2022-07-15  Óbito pelo COVID-19
# 968067   CARIACICA                  Sim  2022-06-29  Óbito pelo COVID-19
# ...            ...                  ...         ...                  ...
# 4724946  CARIACICA                  Sim  2020-06-19  Óbito pelo COVID-19
# 4725771  CARIACICA                  Sim  2020-05-08  Óbito pelo COVID-19
# 4730142  CARIACICA                  Sim  2020-05-10  Óbito pelo COVID-19
# 4730683  CARIACICA                  Sim  2020-05-05  Óbito pelo COVID-19
# 4740642  CARIACICA                  Sim  2020-04-21  Óbito pelo COVID-19
#
# [73 rows x 4 columns]
